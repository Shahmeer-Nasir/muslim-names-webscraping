# %% [markdown]
# Extracting Muslim boys and girls names from hamariweb.com

# %%
# Importing libraries
from bs4 import BeautifulSoup as bs
import requests

# %%
# Creating url
# Sample url 'https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-2'

base_url = 'https://hamariweb.com/names/muslim-'
def get_url(gender, letter, page_num):
  return base_url + gender + '-names-starting-with-' + letter + '/page-' + str(page_num)

# %%
# Extract names from webpage

def get_names_data(soup, name_count, total_names):
  names_in_eng_urd = []
  for td in soup.find_all('td'): # Find all <td> tags
    if td.a == None:
      continue # Ignore <td> tags having no attribute
    else:
      names_in_eng_urd.append(td.a.string)
  names_in_eng = []
  for idx, name in enumerate(names_in_eng_urd):
    if(idx % 2 != 0):
      continue # Ignoring <td> tags having names in urdu
    else:
      names_in_eng.append(name)
      name_count += 1
  if name_count == total_names:
    return names_in_eng, name_count, True
  else:
    return names_in_eng, name_count, False

# %%
# Function to determine how many records (names) are there of each 
# English alphabet. This is important to be known so that our names 
# extracting loop knows how far it has to fetch data from.
# Note: It is specific to hamariweb.com html DOM structure.

def get_total_num_of_names(gender, letter):
  r = requests.get('https://hamariweb.com/names/muslim-' + gender + '-names-starting-with-' + letter + '/page-1')
  soup = bs(r.content)
  total_records_div = soup.find('div', {"class": "record_txt"})
  if total_records_div == None:
    td_tags = soup.find_all('td')
    return int(len(td_tags)/3)
  else:
    total_records_div_str = total_records_div.string
    total_records_div_list = total_records_div_str.split()
    total_records_div_list
    for idx, item in enumerate(total_records_div_list):
      if item == '(Total':
        return int(total_records_div_list[idx + 1])

# %%
# Just to test hardcodedly the number of names for an alphabet.
get_total_num_of_names('girl', 'x')
# Out:
# 2

# %%
# Iterating through each page in alphabetical order
from string import ascii_lowercase as alc # For English alphabetical iteration

# Prompt for names gender
response = int(input("Enter 0 for boy or 1 for girl:"))
if response == 0:
  gender = 'boy'
elif response == 1:
  gender = 'girl'
else:
  print("Wrong input! Now extracting names for boy.")
  gender = 'boy'

all_names = [] # Final output list of names extracted, initially empty.
page_num_limit = 101 # Default limit of pages to be checked

for letter in alc:
  total_names = get_total_num_of_names(gender, letter) # Total no. of names for each alphabet
  break_loop = False
  name_count = 0

  for page_num in range(1, page_num_limit):
    print(letter, page_num) # Shows the current alphabet and page number
    full_url = get_url(gender, letter, page_num)
    print(full_url) # Shows complete URL
    r = requests.get(full_url)
    soup = bs(r.content)
    names_list, name_count, break_loop = get_names_data(soup, name_count, total_names)
    all_names.extend(names_list)
    if break_loop:
      # Loop for the current alphabet will break if iterations reach 
      # total no. of names for that alphabet.
      break
      
# Shahmeer Nasir from Bahria University
# Out:
# Enter 0 for boy or 1 for girl:0
# a 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-1
# a 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-2
# a 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-3
# a 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-4
# a 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-5
# a 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-6
# a 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-7
# a 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-8
# a 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-9
# a 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-10
# a 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-11
# a 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-12
# a 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-13
# a 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-14
# a 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-15
# a 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-16
# a 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-17
# a 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-18
# a 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-19
# a 20
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-20
# a 21
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-21
# a 22
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-22
# a 23
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-23
# a 24
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-24
# a 25
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-25
# a 26
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-26
# a 27
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-27
# a 28
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-28
# a 29
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-29
# a 30
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-30
# a 31
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-31
# a 32
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-32
# a 33
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-33
# a 34
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-34
# a 35
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-35
# a 36
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-36
# a 37
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-37
# a 38
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-38
# a 39
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-39
# a 40
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-40
# a 41
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-41
# a 42
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-42
# a 43
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-43
# a 44
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-44
# a 45
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-45
# a 46
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-46
# a 47
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-47
# a 48
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-48
# a 49
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-49
# a 50
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-50
# a 51
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-51
# a 52
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-52
# a 53
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-53
# a 54
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-54
# a 55
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-55
# a 56
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-56
# a 57
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-57
# a 58
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-58
# a 59
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-59
# a 60
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-60
# a 61
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-61
# a 62
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-62
# a 63
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-63
# a 64
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-64
# a 65
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-65
# a 66
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-66
# a 67
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-67
# a 68
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-68
# a 69
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-69
# a 70
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-70
# a 71
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-71
# a 72
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-72
# a 73
# https://hamariweb.com/names/muslim-boy-names-starting-with-a/page-73
# b 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-1
# b 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-2
# b 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-3
# b 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-4
# b 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-5
# b 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-6
# b 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-7
# b 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-8
# b 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-9
# b 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-10
# b 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-11
# b 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-12
# b 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-13
# b 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-14
# b 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-15
# b 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-16
# b 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-17
# b 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-b/page-18
# c 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-c/page-1
# c 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-c/page-2
# c 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-c/page-3
# c 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-c/page-4
# d 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-1
# d 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-2
# d 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-3
# d 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-4
# d 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-5
# d 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-6
# d 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-7
# d 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-8
# d 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-9
# d 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-10
# d 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-11
# d 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-12
# d 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-13
# d 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-14
# d 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-d/page-15
# e 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-e/page-1
# e 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-e/page-2
# e 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-e/page-3
# e 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-e/page-4
# f 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-1
# f 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-2
# f 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-3
# f 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-4
# f 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-5
# f 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-6
# f 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-7
# f 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-8
# f 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-9
# f 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-10
# f 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-11
# f 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-12
# f 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-13
# f 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-14
# f 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-15
# f 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-16
# f 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-17
# f 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-18
# f 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-19
# f 20
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-20
# f 21
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-21
# f 22
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-22
# f 23
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-23
# f 24
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-24
# f 25
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-25
# f 26
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-26
# f 27
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-27
# f 28
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-28
# f 29
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-29
# f 30
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-30
# f 31
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-31
# f 32
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-32
# f 33
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-33
# f 34
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-34
# f 35
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-35
# f 36
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-36
# f 37
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-37
# f 38
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-38
# f 39
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-39
# f 40
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-40
# f 41
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-41
# f 42
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-42
# f 43
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-43
# f 44
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-44
# f 45
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-45
# f 46
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-46
# f 47
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-47
# f 48
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-48
# f 49
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-49
# f 50
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-50
# f 51
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-51
# f 52
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-52
# f 53
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-53
# f 54
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-54
# f 55
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-55
# f 56
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-56
# f 57
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-57
# f 58
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-58
# f 59
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-59
# f 60
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-60
# f 61
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-61
# f 62
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-62
# f 63
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-63
# f 64
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-64
# f 65
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-65
# f 66
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-66
# f 67
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-67
# f 68
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-68
# f 69
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-69
# f 70
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-70
# f 71
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-71
# f 72
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-72
# f 73
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-73
# f 74
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-74
# f 75
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-75
# f 76
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-76
# f 77
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-77
# f 78
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-78
# f 79
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-79
# f 80
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-80
# f 81
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-81
# f 82
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-82
# f 83
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-83
# f 84
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-84
# f 85
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-85
# f 86
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-86
# f 87
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-87
# f 88
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-88
# f 89
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-89
# f 90
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-90
# f 91
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-91
# f 92
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-92
# f 93
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-93
# f 94
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-94
# f 95
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-95
# f 96
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-96
# f 97
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-97
# f 98
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-98
# f 99
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-99
# f 100
# https://hamariweb.com/names/muslim-boy-names-starting-with-f/page-100
# g 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-1
# g 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-2
# g 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-3
# g 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-4
# g 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-5
# g 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-6
# g 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-7
# g 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-8
# g 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-9
# g 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-10
# g 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-11
# g 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-12
# g 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-13
# g 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-g/page-14
# h 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-1
# h 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-2
# h 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-3
# h 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-4
# h 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-5
# h 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-6
# h 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-7
# h 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-8
# h 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-9
# h 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-10
# h 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-11
# h 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-12
# h 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-13
# h 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-14
# h 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-15
# h 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-16
# h 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-17
# h 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-18
# h 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-19
# h 20
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-20
# h 21
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-21
# h 22
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-22
# h 23
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-23
# h 24
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-24
# h 25
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-25
# h 26
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-26
# h 27
# https://hamariweb.com/names/muslim-boy-names-starting-with-h/page-27
# i 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-1
# i 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-2
# i 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-3
# i 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-4
# i 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-5
# i 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-6
# i 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-7
# i 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-8
# i 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-9
# i 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-10
# i 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-11
# i 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-i/page-12
# j 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-1
# j 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-2
# j 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-3
# j 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-4
# j 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-5
# j 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-6
# j 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-7
# j 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-8
# j 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-9
# j 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-10
# j 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-11
# j 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-j/page-12
# k 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-1
# k 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-2
# k 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-3
# k 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-4
# k 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-5
# k 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-6
# k 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-7
# k 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-8
# k 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-9
# k 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-10
# k 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-11
# k 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-12
# k 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-13
# k 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-14
# k 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-15
# k 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-16
# k 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-17
# k 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-18
# k 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-19
# k 20
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-20
# k 21
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-21
# k 22
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-22
# k 23
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-23
# k 24
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-24
# k 25
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-25
# k 26
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-26
# k 27
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-27
# k 28
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-28
# k 29
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-29
# k 30
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-30
# k 31
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-31
# k 32
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-32
# k 33
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-33
# k 34
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-34
# k 35
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-35
# k 36
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-36
# k 37
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-37
# k 38
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-38
# k 39
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-39
# k 40
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-40
# k 41
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-41
# k 42
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-42
# k 43
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-43
# k 44
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-44
# k 45
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-45
# k 46
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-46
# k 47
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-47
# k 48
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-48
# k 49
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-49
# k 50
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-50
# k 51
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-51
# k 52
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-52
# k 53
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-53
# k 54
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-54
# k 55
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-55
# k 56
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-56
# k 57
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-57
# k 58
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-58
# k 59
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-59
# k 60
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-60
# k 61
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-61
# k 62
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-62
# k 63
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-63
# k 64
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-64
# k 65
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-65
# k 66
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-66
# k 67
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-67
# k 68
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-68
# k 69
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-69
# k 70
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-70
# k 71
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-71
# k 72
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-72
# k 73
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-73
# k 74
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-74
# k 75
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-75
# k 76
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-76
# k 77
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-77
# k 78
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-78
# k 79
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-79
# k 80
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-80
# k 81
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-81
# k 82
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-82
# k 83
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-83
# k 84
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-84
# k 85
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-85
# k 86
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-86
# k 87
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-87
# k 88
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-88
# k 89
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-89
# k 90
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-90
# k 91
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-91
# k 92
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-92
# k 93
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-93
# k 94
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-94
# k 95
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-95
# k 96
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-96
# k 97
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-97
# k 98
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-98
# k 99
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-99
# k 100
# https://hamariweb.com/names/muslim-boy-names-starting-with-k/page-100
# l 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-l/page-1
# l 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-l/page-2
# l 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-l/page-3
# l 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-l/page-4
# l 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-l/page-5
# l 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-l/page-6
# m 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-1
# m 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-2
# m 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-3
# m 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-4
# m 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-5
# m 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-6
# m 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-7
# m 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-8
# m 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-9
# m 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-10
# m 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-11
# m 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-12
# m 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-13
# m 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-14
# m 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-15
# m 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-16
# m 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-17
# m 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-18
# m 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-19
# m 20
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-20
# m 21
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-21
# m 22
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-22
# m 23
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-23
# m 24
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-24
# m 25
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-25
# m 26
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-26
# m 27
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-27
# m 28
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-28
# m 29
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-29
# m 30
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-30
# m 31
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-31
# m 32
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-32
# m 33
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-33
# m 34
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-34
# m 35
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-35
# m 36
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-36
# m 37
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-37
# m 38
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-38
# m 39
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-39
# m 40
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-40
# m 41
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-41
# m 42
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-42
# m 43
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-43
# m 44
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-44
# m 45
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-45
# m 46
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-46
# m 47
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-47
# m 48
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-48
# m 49
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-49
# m 50
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-50
# m 51
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-51
# m 52
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-52
# m 53
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-53
# m 54
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-54
# m 55
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-55
# m 56
# https://hamariweb.com/names/muslim-boy-names-starting-with-m/page-56
# n 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-1
# n 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-2
# n 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-3
# n 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-4
# n 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-5
# n 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-6
# n 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-7
# n 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-8
# n 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-9
# n 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-10
# n 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-11
# n 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-12
# n 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-13
# n 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-14
# n 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-15
# n 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-16
# n 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-17
# n 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-18
# n 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-n/page-19
# o 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-o/page-1
# o 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-o/page-2
# p 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-p/page-1
# p 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-p/page-2
# p 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-p/page-3
# q 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-1
# q 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-2
# q 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-3
# q 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-4
# q 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-5
# q 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-6
# q 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-7
# q 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-8
# q 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-9
# q 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-q/page-10
# r 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-1
# r 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-2
# r 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-3
# r 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-4
# r 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-5
# r 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-6
# r 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-7
# r 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-8
# r 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-9
# r 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-10
# r 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-11
# r 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-12
# r 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-13
# r 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-14
# r 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-15
# r 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-16
# r 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-17
# r 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-18
# r 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-r/page-19
# s 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-1
# s 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-2
# s 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-3
# s 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-4
# s 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-5
# s 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-6
# s 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-7
# s 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-8
# s 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-9
# s 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-10
# s 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-11
# s 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-12
# s 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-13
# s 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-14
# s 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-15
# s 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-16
# s 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-17
# s 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-18
# s 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-19
# s 20
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-20
# s 21
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-21
# s 22
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-22
# s 23
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-23
# s 24
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-24
# s 25
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-25
# s 26
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-26
# s 27
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-27
# s 28
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-28
# s 29
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-29
# s 30
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-30
# s 31
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-31
# s 32
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-32
# s 33
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-33
# s 34
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-34
# s 35
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-35
# s 36
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-36
# s 37
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-37
# s 38
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-38
# s 39
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-39
# s 40
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-40
# s 41
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-41
# s 42
# https://hamariweb.com/names/muslim-boy-names-starting-with-s/page-42
# t 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-1
# t 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-2
# t 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-3
# t 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-4
# t 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-5
# t 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-6
# t 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-7
# t 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-8
# t 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-9
# t 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-10
# t 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-11
# t 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-12
# t 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-13
# t 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-14
# t 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-15
# t 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-16
# t 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-17
# t 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-18
# t 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-t/page-19
# u 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-u/page-1
# u 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-u/page-2
# u 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-u/page-3
# u 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-u/page-4
# v 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-v/page-1
# w 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-1
# w 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-2
# w 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-3
# w 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-4
# w 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-5
# w 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-6
# w 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-7
# w 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-8
# w 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-w/page-9
# x 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-x/page-1
# y 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-y/page-1
# y 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-y/page-2
# y 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-y/page-3
# y 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-y/page-4
# y 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-y/page-5
# y 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-y/page-6
# y 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-y/page-7
# z 1
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-1
# z 2
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-2
# z 3
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-3
# z 4
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-4
# z 5
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-5
# z 6
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-6
# z 7
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-7
# z 8
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-8
# z 9
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-9
# z 10
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-10
# z 11
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-11
# z 12
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-12
# z 13
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-13
# z 14
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-14
# z 15
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-15
# z 16
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-16
# z 17
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-17
# z 18
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-18
# z 19
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-19
# z 20
# https://hamariweb.com/names/muslim-boy-names-starting-with-z/page-20

# %%
print(all_names) # Displaying extracted names
# Out:
# ['Arham', 'Ayan', 'Ayaan', 'Aryan', 'Anas', 'Azlan', 'Ali', 'Aayan', 'Arish', 'Adnan', 'Asif', 'Asad', 'Abdullah', 'Ahad', 'Arabi', 'Ahmed', 'Ayaz', 'Aaron', 'Afan', 'Abrar', 'Aman', 'Ahmad', 'Arsalan', 'Ahil', 'Abaan', 'Adyan', 'Arif', 'Azhar', 'Azan', 'Aamir', 'Azaan', 'Abu-Turab', 'Ammar', 'Arshan', 'Arshad', 'Abir', 'Atif', 'Azhaan', 'Ahnaf', 'Abeer', 'Arab', 'Abbas', 'Ayman', 'Ahsan', 'Aabid', 'Ashar', 'Adan', 'Arafat', 'Aban', 'Aasim', 'Ahtisham', 'Ameen', 'Arslan', 'Aftab', 'Aqib', 'Abid', 'Alam', 'Adil', 'Amaan', 'Aadil', 'Aaqib', 'Altamash', 'Anwar', 'Akhtar', 'Armaan', 'Ariz', 'Aslam', 'Abu Zar', 'Arfan', 'Arbaaz', 'Amir', 'Abad', 'Arash', 'Afzal', 'Aahid', 'Aakif', 'Alif', 'Abdul', 'Altaf', 'Akram', 'Amjad', 'Azeem', 'Aafeen', 'Aarib', 'Abu hurairah', 'Asim', 'Ashfaq', 'Aslan', 'Arman', 'Aafi', 'Abdul-hadi', 'Arsal', 'Arshman', 'Aadam', 'Al Amin', 'Afaq', 'Ayyan', 'Abdul Ahad', 'Aziz', 'Abraham', 'Abu', 'Ashiq', 'Akhi', 'Ansari', 'Ashir', 'Akbar', 'Afraz', 'Akhil', 'Ayyash', 'Aabinus', 'Areeb', 'Abu-bakr', 'Anis', 'Azad', 'Afridi', 'Adib', 'Azam', 'Aadeel', 'Antar', 'Aarzam', 'Abdul Hannan', 'Aabideen', 'Athar', 'Abdul-rahman', 'Azim', 'Abdur-rahman', 'Anees', 'Al', 'Ababil', 'Aswad', 'Al Faiz', 'Aftar', 'Adeel', 'Ahmar', 'Azal', 'Aas', 'Abubakar', 'Ansar', 'Anjum', 'Ayub', 'Ajmal', 'Amin', 'Almir', 'Abdul Rafay', 'Arqam', 'Ahyan', 'Aun', 'Ashura', 'Aalam', 'Adam', 'Aaid', 'Ali Raza', 'Aarif', 'Altan', 'Amad', 'Aurangzeb', 'Aqeel', "Ab'ab", 'Aydin', 'Aaiez', 'Ahmadullah', 'Arsel', 'Adrish', 'Aameen', 'Adeeb', 'Aleem', 'Arbab', 'Aafreen', 'Ali Hassan', 'Anzar', 'Alauddin', 'Azar', 'Abdul Mannan', 'Afif', 'Aadroop', 'Adal', 'Abdul Rehman', 'Aafsar', 'Aish', 'Alim', 'Abdul-basit', 'Abdul-samad', 'Aatazaz', 'Awais', 'Aamin', 'Aisa', 'Ateeq', 'Alamgir', 'Aaien', 'Arad', 'Aamad', 'Abu Talha', 'Ashab', 'Akif', 'Abdul-bari', 'Aazam', 'Aasil', 'Arhaam', 'Aamil', 'Armin', 'Arkan', 'Ashrafi', "A'azz", 'Aamer', 'Atik', 'Ali Haider', 'Abdel', 'Awan', 'Amanullah', 'Aaghaa', 'Azmi', 'Aalim', 'Afiyat', 'Aayed', 'Abdul-muiz', 'Arafah', 'Aalif', 'Abdul muttalib', 'Abdul-wahab', 'Aasaf', 'Adad', 'Adi', 'Asadullah', 'Atiq', 'Abdul Qadir', 'Abd manaf', 'Abdul-muhaimin', 'Aati', 'Ain', 'Ayad', 'Ashaz', 'Amal', 'Aaied', 'Anayat', 'Aaki', 'Asmar', 'Akil', 'Aasaal', 'Abdul-aziz', 'Abdul-rehman', 'Akmal', 'Amil', 'Ali Hamza', 'Arfeen', 'Abar', 'Akhlaq', 'Abyan', 'Areesh', 'Abdul Waase', 'Amer', 'Aulad', 'Araiz', 'Aly', 'Ada', 'Arib', 'Asgar', 'Ara', 'Auliya', 'Aliyar', 'Aabbaz', 'Abdul Qayyum', 'Asel', 'Afshin', 'Aagha', 'Asaf', 'Abdi', 'Aarzu', 'Alman', 'Aqdas', 'Azab', 'Aladdin', 'Asghar', 'Abis', 'Abadi', 'Aaghaa', 'Absar', 'Ali Sher', "As'ad", 'Abbasi', 'Abaid', 'Aoun', 'Ahkam', 'Amatullah', 'afi', 'Abdul-rauf', 'Abdul-mateen', 'Alp', 'Aafaq', 'Adham', 'Asar', 'Ayyub', 'Aaaqil', 'Abul Kalam', 'Afham', 'Abdal', 'Abdul Rahim', 'Ali Akbar', 'Aabed', 'Ayar', 'Ayoub', 'Areez', 'Arsham', 'Ali Asghar', 'Avir', 'Aibak', 'Asam', 'Arifin', 'Arvin', 'Abul bashar', 'Aaqaa', 'Abdul Sattar', 'Arjan', 'Aafandi', 'Asil', 'Arya', 'Abadullah', 'Aabaad', 'Abul hasan', 'Aadar', 'Abdul razzaq', 'Asaad', 'Aza', 'Aazaad', 'Aabes', 'Aufar', 'Amr', 'Aafien', 'Abu Talib', 'Adalat', 'Arda', 'Aaess', 'Aahil', 'Alai', 'Ashmal', 'Askar', 'Aaeze', 'Asmir', 'Abdal-hadi', 'Aalamgeer', 'Awad', 'Azfar', 'Abdaal', 'Abu Saeed', 'Abaj', 'Abdul-majid', 'Asir', 'Alhan', 'Amiri', 'Ayur', 'Arhab', 'Afzaal', 'Ali Shan', 'Ataur Rahman', 'Ausaf', 'Abdul-wahid', 'Abd', 'Alva', 'Atlas', 'Aiz', 'Ashkan', 'Ata', "Al-yasa'", 'Atish', 'Aban', 'Aron', 'Afandi', 'Abdul-salam', 'Abdan', 'Abd-al-jabbar', 'Anif', 'Asbah', 'Azain', 'Aniq', 'Allama', 'Azmeer', 'Abdar', 'Afeef', 'Ajim', 'Abdul-hameed', 'Abba', 'Amanat', 'Ataullah', 'Aneeq', 'Abadah', 'Abdul-ghaffar', 'Awaiz', 'Abu lahab', 'Arwah', 'Arz', 'Ajwad', 'Azizi', 'Aslihan', 'Abdul-quddus', 'Abadard', 'Anosha', 'Al Rafi', 'Ariq', 'Azzam', 'Adim', 'Aqrab', 'Ameer', 'Auf', 'Abdul-jabbar', 'Abdu', 'Aqil', 'Aqidah', 'Abraz', 'Asadi', 'Azil', ...

# %%
len(all_names) # Number of names extracted
# Out:
# 12827

# %%
# Checking if the list contains any emtpy element
for idx, name in enumerate(all_names):
  if name == '':
    print('{}. Empty'.format(idx))

# %%
# Saving names list in a text file
with open(gender + '.txt', 'w') as output:
  for name in all_names:
    output.write(str(name) + '\n')

# %%
# Shahmeer Nasir from Bahria University
